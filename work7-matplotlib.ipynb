# %%
Continuing working on matplotlib
# Out:
#   Cell In[1], line 1
#     Continuing working on matplotlib
#                ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
#Making an histogram and wroking with it
a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title("histogram")
plt.show()

# %%
BOX PLOT using Matplotlib
# Out:
#   Cell In[13], line 1
#     BOX PLOT using Matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]

plt.boxplot(data,vert=False,patch_artist=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ed3fd1d450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ed3fd1e250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ed3fd1cb50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1ed3fd1f750>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1ed3fd2c050>,
# ...
#  'means': []}

# %%
#Pie charts
labels='Python','C++','Ruby','Java'
sizes=[215,130,245,210]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0.2,0,0,0)

plt.pie(sizes, explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False)

plt.axis('equal')
plt.show()
